# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA


client = ChatNVIDIA(
  model="deepseek-ai/deepseek-v4-flash",
  api_key="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",
  temperature=1,
  top_p=0.95,
  max_completion_tokens=16384,
    timeout=6000
)

response = client.invoke([
  {"role":"system",
   "content":"너는 분석가야"
  },
  {"role":"user",
               "content": """
다음 작업을 순서대로 전부 수행해줘:

1. 최근 5년간 한국 인터넷 신조어 50개를 나열하고
   각각의 뜻, 어원, 유행 시기, 사용 맥락을 상세히 설명해줘

2. 각 신조어가 어떤 커뮤니티에서 시작됐는지 분석해줘

3. 신조어들 사이의 연관관계를 분석해줘

4. 앞으로 유행할 것 같은 신조어 트렌드를 예측해줘
"""
   }

])
reasoning = response.additional_kwargs.get("reasoning") or response.additional_kwargs.get("reasoning_content") if response.additional_kwargs else None
if reasoning:
  print(reasoning)
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[16], line 13
#       9   max_completion_tokens=16384,
#      10     timeout=6000
#      11 )
#      12
# ---> 13 response = client.invoke([
#      14   {"role":"system",
#      15    "content":"너는 분석가야"
#      16   },
#
# File C:\workspace\memeory\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
# ...
